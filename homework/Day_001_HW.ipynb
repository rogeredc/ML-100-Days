# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    sums=0
    for i in range(len(y)):
        sums +=(y[i]-y_hat[i])**2
    MSE=sums/len(y)
    return MSE
def mean_absolute_error(y,y_hat):
    suma=0
    for i in range(len(y)):
        suma +=abs(y[i]-y_hat[i])
    MAE=suma/len(y)
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 237.296
# The Mean absolute error is 12.273

# %%
hw 1
我選擇Wine Reviews:130k wine reviews with variety, location, winery, price, and description
1.這個數據集合了不同葡萄酒的資訊．希望透過模型的建立做出能夠盲測出葡萄酒的種類
2.這個數據是WineEnthusiast網站 June 15th, 2017搜集的資料，上面有各種葡萄酒的資訊，包含葡萄品種、產地、價格等等
3.資料為一個csv檔，資料有數值與文字值，裡面包含
countryThe: country that the wine is from
description
designation:The vineyard within the winery where the grapes that made the wine are from
points:The number of points WineEnthusiast rated the wine on a scale of 1-100 (though they say they only post reviews for wines that score >=80)
price:The cost for a bottle of the wine
province:The province or state that the wine is from
region_1:The wine growing area in a province or state (ie Napa)
region_2:Sometimes there are more specific regions specified within a wine growing area (ie Rutherford inside the Napa Valley), but this value can sometimes be blank
taster_name
taster_twitter_handle
title:The title of the wine review, which often contains the vintage if you're interested in extracting that feature
variety:The type of grapes used to make the wine (ie Pinot Noir)
winery:The winery that made the wine
    
4.需要能夠基於以上的資訊建構出模型辨識出葡萄酒的種類、酒廠、產地 用準確率評估模型的好壞

# %%
hw2
1.載客業績提升有兩種：載客數量提升或是載到客人都到比較遠的地方 可以假設每日有乘客在車上的累積時間為業績提升的依據
2.資料可以從線上叫車的乘客資訊或是在車上架設蒐集乘客資料的機器
3.為乘客的乘車起訖點，乘客性別年齡等結構化資料
4.統計不同時間地點的乘車資訊，預測不同時間在何處能夠載客的機率最高，給予司機載客地點推薦，觀察司機的乘客在車上總時間有無提高
